# %% [markdown]
# # NBA Immaculate Grid Application
#
# This program imports NBA box score data from the SportsDataVerse to create an "immaculate grid" application, a game where two NBA franchises are selected at random and the user is prompted to input the name of a player who has played at least one game for each of the teams between the 2014 and 2024 NBA seasons. After the user inputs their selection, the program will indicate whether their selection was correct, as well as print a list of all eligible players for the category.

# %% [markdown]
# #### Importing libraries:

# %%
import pandas as pd
import numpy as np
import random 
import sportsdataverse as sdv

pd.set_option('display.max_columns', 100)

# %% [markdown]
# #### Accessing NBA data through sportsdataverse:

# %%
nba_data = sdv.nba.load_nba_player_boxscore(seasons = range(2014, 2025), return_as_pandas = True)
# Out:
# 100%|██████████| 11/11 [00:07<00:00,  1.51it/s]

# %% [markdown]
# #### Performing some initial data inspection:

# %%
nba_data.head()
# Out:
#      game_id  season  season_type  game_date             game_date_time  \
# 0  400559378    2014            3 2014-06-15  2014-06-15 20:00:00-04:00
# 1  400559378    2014            3 2014-06-15  2014-06-15 20:00:00-04:00
# 2  400559378    2014            3 2014-06-15  2014-06-15 20:00:00-04:00
# 3  400559378    2014            3 2014-06-15  2014-06-15 20:00:00-04:00
# 4  400559378    2014            3 2014-06-15  2014-06-15 20:00:00-04:00
#
#    athlete_id athlete_display_name  team_id team_name team_location  \
# 0         469        Rashard Lewis       14      Heat         Miami
# 1        1977           Chris Bosh       14      Heat         Miami
# 2        1966         LeBron James       14      Heat         Miami
# 3           9            Ray Allen       14      Heat         Miami
# 4        1987          Dwyane Wade       14      Heat         Miami
#
#   team_short_display_name  minutes  field_goals_made  field_goals_attempted  \
# 0                    Heat      9.0                 1                      2
# 1                    Heat     39.0                 6                     14
# 2                    Heat     41.0                10                     21
# 3                    Heat     31.0                 1                      8
# 4                    Heat     36.0                 4                     12
#
#    three_point_field_goals_made  three_point_field_goals_attempted  \
# 0                             1                                  2
# 1                             0                                  5
# 2                             3                                  9
# 3                             1                                  3
# 4                             1                                  2
#
#    free_throws_made  free_throws_attempted  offensive_rebounds  \
# 0                 0                      0                   0
# 1                 1                      2                   0
# 2                 8                      9                   1
# 3                 2                      2                   1
# 4                 2                      4                   0
#
#    defensive_rebounds  rebounds  assists  steals  blocks  turnovers  fouls  \
# 0                   2         2        1       0       0          0      2
# 1                   7         7        2       1       0          0      2
# 2                   9        10        5       0       2          1      1
# 3                   4         5        2       1       0          4      2
# 4                   3         3        1       0       0          3      3
#
#   plus_minus  points starter ejected did_not_play            reason active  \
# 0         +8       3    True   False        False  COACH'S DECISION  False
# 1        -20      13    True   False        False  COACH'S DECISION  False
# 2        -16      31    True   False        False  COACH'S DECISION  False
# 3        -18       5    True   False        False  COACH'S DECISION  False
# 4        -10      11    True   False        False  COACH'S DECISION  False
#
#   athlete_jersey athlete_short_name  \
# 0              9           R. Lewis
# 1              1            C. Bosh
# 2              6           L. James
# 3             34           R. Allen
# 4              3            D. Wade
#
#                                athlete_headshot_href athlete_position_name  \
# 0  https://a.espncdn.com/i/headshots/nba/players/...         Power Forward
# 1  https://a.espncdn.com/i/headshots/nba/players/...         Power Forward
# 2  https://a.espncdn.com/i/headshots/nba/players/...         Small Forward
# 3  https://a.espncdn.com/i/headshots/nba/players/...        Shooting Guard
# 4  https://a.espncdn.com/i/headshots/nba/players/...                 Guard
#
#   athlete_position_abbreviation team_display_name        team_uid   team_slug  \
# 0                            PF        Miami Heat  s:40~l:46~t:14  miami-heat
# 1                            PF        Miami Heat  s:40~l:46~t:14  miami-heat
# 2                            SF        Miami Heat  s:40~l:46~t:14  miami-heat
# 3                            SG        Miami Heat  s:40~l:46~t:14  miami-heat
# 4                             G        Miami Heat  s:40~l:46~t:14  miami-heat
#
#                                            team_logo team_abbreviation  \
# 0  https://a.espncdn.com/i/teamlogos/nba/500/mia.png               MIA
# 1  https://a.espncdn.com/i/teamlogos/nba/500/mia.png               MIA
# 2  https://a.espncdn.com/i/teamlogos/nba/500/mia.png               MIA
# 3  https://a.espncdn.com/i/teamlogos/nba/500/mia.png               MIA
# 4  https://a.espncdn.com/i/teamlogos/nba/500/mia.png               MIA
#
#   team_color team_alternate_color home_away team_winner  team_score  \
# 0     000000               000000      away       False          87
# 1     000000               000000      away       False          87
# 2     000000               000000      away       False          87
# 3     000000               000000      away       False          87
# 4     000000               000000      away       False          87
#
#    opponent_team_id opponent_team_name opponent_team_location  \
# 0                24              Spurs            San Antonio
# 1                24              Spurs            San Antonio
# 2                24              Spurs            San Antonio
# 3                24              Spurs            San Antonio
# 4                24              Spurs            San Antonio
#
#   opponent_team_display_name opponent_team_abbreviation  \
# 0          San Antonio Spurs                         SA
# 1          San Antonio Spurs                         SA
# 2          San Antonio Spurs                         SA
# 3          San Antonio Spurs                         SA
# 4          San Antonio Spurs                         SA
#
#                                  opponent_team_logo opponent_team_color  \
# 0  https://a.espncdn.com/i/teamlogos/nba/500/sa.png              000000
# 1  https://a.espncdn.com/i/teamlogos/nba/500/sa.png              000000
# 2  https://a.espncdn.com/i/teamlogos/nba/500/sa.png              000000
# 3  https://a.espncdn.com/i/teamlogos/nba/500/sa.png              000000
# 4  https://a.espncdn.com/i/teamlogos/nba/500/sa.png              000000
#
#   opponent_team_alternate_color  opponent_team_score
# 0                        061922                  104
# 1                        061922                  104
# 2                        061922                  104
# 3                        061922                  104
# 4                        061922                  104

# %%
nba_data.shape
# Out:
# (348577, 57)

# %%
nba_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348577 entries, 0 to 348576
# Data columns (total 57 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   game_id                            348577 non-null  int32[pyarrow]
#  1   season                             348577 non-null  int32[pyarrow]
#  2   season_type                        348577 non-null  int32[pyarrow]
#  3   game_date                          348577 non-null  date32[day][pyarrow]
#  4   game_date_time                     348577 non-null  timestamp[us, tz=America/New_York][pyarrow]
#  5   athlete_id                         348577 non-null  int32[pyarrow]
#  6   athlete_display_name               348577 non-null  large_string[pyarrow]
#  7   team_id                            348577 non-null  int32[pyarrow]
#  8   team_name                          348577 non-null  large_string[pyarrow]
#  9   team_location                      348577 non-null  large_string[pyarrow]
#  10  team_short_display_name            348577 non-null  large_string[pyarrow]
#  11  minutes                            287728 non-null  double[pyarrow]
#  12  field_goals_made                   287728 non-null  int32[pyarrow]
#  13  field_goals_attempted              287728 non-null  int32[pyarrow]
#  14  three_point_field_goals_made       287728 non-null  int32[pyarrow]
#  15  three_point_field_goals_attempted  287728 non-null  int32[pyarrow]
#  16  free_throws_made                   287728 non-null  int32[pyarrow]
#  17  free_throws_attempted              287728 non-null  int32[pyarrow]
#  18  offensive_rebounds                 287728 non-null  int32[pyarrow]
#  19  defensive_rebounds                 287728 non-null  int32[pyarrow]
#  20  rebounds                           287728 non-null  int32[pyarrow]
#  21  assists                            287728 non-null  int32[pyarrow]
#  22  steals                             287728 non-null  int32[pyarrow]
#  23  blocks                             287728 non-null  int32[pyarrow]
#  24  turnovers                          287728 non-null  int32[pyarrow]
#  25  fouls                              287728 non-null  int32[pyarrow]
#  26  plus_minus                         287857 non-null  large_string[pyarrow]
#  27  points                             287728 non-null  int32[pyarrow]
#  28  starter                            348577 non-null  bool[pyarrow]
#  29  ejected                            348577 non-null  bool[pyarrow]
#  30  did_not_play                       348577 non-null  bool[pyarrow]
#  31  reason                             347215 non-null  large_string[pyarrow]
#  32  active                             348577 non-null  bool[pyarrow]
#  33  athlete_jersey                     344769 non-null  large_string[pyarrow]
#  34  athlete_short_name                 348577 non-null  large_string[pyarrow]
#  35  athlete_headshot_href              348224 non-null  large_string[pyarrow]
#  36  athlete_position_name              348577 non-null  large_string[pyarrow]
#  37  athlete_position_abbreviation      348577 non-null  large_string[pyarrow]
#  38  team_display_name                  348577 non-null  large_string[pyarrow]
#  39  team_uid                           348577 non-null  large_string[pyarrow]
#  40  team_slug                          348577 non-null  large_string[pyarrow]
#  41  team_logo                          347475 non-null  large_string[pyarrow]
#  42  team_abbreviation                  348577 non-null  large_string[pyarrow]
#  43  team_color                         348271 non-null  large_string[pyarrow]
#  44  team_alternate_color               348271 non-null  large_string[pyarrow]
#  45  home_away                          348577 non-null  large_string[pyarrow]
#  46  team_winner                        348577 non-null  bool[pyarrow]
#  47  team_score                         348577 non-null  int32[pyarrow]
#  48  opponent_team_id                   348577 non-null  int32[pyarrow]
#  49  opponent_team_name                 348577 non-null  large_string[pyarrow]
#  50  opponent_team_location             348577 non-null  large_string[pyarrow]
#  51  opponent_team_display_name         348577 non-null  large_string[pyarrow]
#  52  opponent_team_abbreviation         348577 non-null  large_string[pyarrow]
#  53  opponent_team_logo                 347483 non-null  large_string[pyarrow]
#  54  opponent_team_color                348271 non-null  large_string[pyarrow]
#  55  opponent_team_alternate_color      348271 non-null  large_string[pyarrow]
#  56  opponent_team_score                348577 non-null  int32[pyarrow]
# dtypes: bool[pyarrow](5), date32[day][pyarrow](1), double[pyarrow](1), int32[pyarrow](23), large_string[pyarrow](26), timestamp[us, tz=America/New_York][pyarrow](1)
# memory usage: 221.6 MB

# %%
nba_data['team_display_name'].unique()
# Out:
# <ArrowExtensionArray>
# [            'Miami Heat',      'San Antonio Spurs',  'Oklahoma City Thunder',
#          'Indiana Pacers',            'LA Clippers',     'Washington Wizards',
#  'Portland Trail Blazers',          'Brooklyn Nets',       'Dallas Mavericks',
#         'Toronto Raptors',  'Golden State Warriors',      'Memphis Grizzlies',
#           'Atlanta Hawks',        'Houston Rockets',          'Chicago Bulls',
#       'Charlotte Bobcats',           'Phoenix Suns',       'Sacramento Kings',
#          'Denver Nuggets',        'Milwaukee Bucks',              'Utah Jazz',
#  'Minnesota Timberwolves',   'New Orleans Pelicans',        'Detroit Pistons',
#      'Los Angeles Lakers',         'Boston Celtics',    'Cleveland Cavaliers',
#      'Philadelphia 76ers',        'New York Knicks',          'Orlando Magic',
#  'Eastern Conf All-Stars', 'Western Conf All-Stars',      'Charlotte Hornets',
#             'Team LeBron',           'Team Stephen',                  'World',
#                     'USA',           'Team Giannis',                    'Leb',
#                     'Usa',            'Team Durant']
# Length: 41, dtype: large_string[pyarrow]

# %% [markdown]
# #### Cleaning the DataFrame:

# %%
# Renaming some columns
nba_data = nba_data.rename(columns = {'athlete_id':'id', 'athlete_display_name':'player', 'team_display_name':'team'})

# Merging both Charlotte teams
nba_data['team'] = np.where(nba_data['team'] == 'Charlotte Bobcats', 'Charlotte Hornets', nba_data['team'])

# Defining a list of ineligible teams
ineligible_teams = ['Team LeBron', 'Eastern Conf All-Stars', 'Western Conf All-Stars', 'Team Giannis', 'World', 
                    'Team Durant', 'USA', 'Leb', 'Team Stephen', 'Usa']

# Creating our condition: if team is in "ineligible", remove it
condition = [True if not (x in ineligible_teams) else False for x in nba_data['team']]

# Applying our condition to the DataFrame
nba_data = nba_data[condition].reset_index(drop = True)

# Only keep necessary columns
nba_data = nba_data[['id', 'player', 'team']]

# %%
nba_data.head()
# Out:
#      id         player        team
# 0   469  Rashard Lewis  Miami Heat
# 1  1977     Chris Bosh  Miami Heat
# 2  1966   LeBron James  Miami Heat
# 3     9      Ray Allen  Miami Heat
# 4  1987    Dwyane Wade  Miami Heat

# %% [markdown]
# #### Aggregating the data:

# %%
# Performing the groupby
nba_grid = nba_data.groupby(['id', 'player'], as_index = False)['team'].unique()

# %%
nba_grid.head()
# Out:
#     id             player                                   team
# 0    9          Ray Allen                           [Miami Heat]
# 1   25  Metta World Peace  [New York Knicks, Los Angeles Lakers]
# 2   63   Chauncey Billups                      [Detroit Pistons]
# 3   91        Elton Brand    [Atlanta Hawks, Philadelphia 76ers]
# 4  110        Kobe Bryant                   [Los Angeles Lakers]

# %% [markdown]
# #### Checking validity of aggregations:

# %%
list(nba_grid[nba_grid['player'] == 'LeBron James']['team'])
# Out:
# [array(['Miami Heat', 'Cleveland Cavaliers', 'Los Angeles Lakers'],
#        dtype=object)]

# %%
list(nba_grid[nba_grid['player'] == 'James Harden']['team'])
# Out:
# [array(['Houston Rockets', 'Brooklyn Nets', 'Philadelphia 76ers',
#         'LA Clippers'], dtype=object)]

# %%
list(nba_grid[nba_grid['player'] == 'Chris Paul']['team'])
# Out:
# [array(['LA Clippers', 'Houston Rockets', 'Oklahoma City Thunder',
#         'Phoenix Suns', 'Golden State Warriors'], dtype=object)]

# %% [markdown]
# #### Creating immaculate grid application:

# %%
def Grid():
    
    # Defining official teams list
    teams = ['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets', 'Charlotte Hornets', 'Chicago Bulls', 
             'Cleveland Cavaliers', 'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons', 'Golden State Warriors', 
             'Houston Rockets', 'Indiana Pacers', 'LA Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies', 
             'Miami Heat', 'Milwaukee Bucks', 'Minnesota Timberwolves', 'New Orleans Pelicans', 'New York Knicks', 
             'Oklahoma City Thunder', 'Orlando Magic', 'Philadelphia 76ers', 'Phoenix Suns', 'Portland Trail Blazers', 
             'Sacramento Kings', 'San Antonio Spurs', 'Toronto Raptors', 'Utah Jazz', 'Washington Wizards']
    
    # Randomly selecting two teams for our grid
    selected_teams = random.sample(teams, 2)
    
    # Filtering DataFrame to only include players who played for both selected teams
    nba_grid_temp = nba_grid[[True if np.isin(selected_teams, x).all() else False for x in nba_grid['team']]]
    
    # Selecting all eligible players
    player_list = list(nba_grid_temp['player'])
    
    # Restarting if length of eligible players list is less than 3
    if (len(player_list) < 3):
        return(Grid())
    
    # Printing the selected teams
    print('Team #1:', selected_teams[0])
    print('Team #2:', selected_teams[1])
    
    # Getting user input
    player = input('\nEnter your player: ')
    
    # Checking if player is in the DataFrame
    if (player in player_list):
        print('\nCorrect!')
    else:
        print('\nIncorrect!')
    
    print('\nEligible players:\n', player_list)

# %% [markdown]
# #### Playing the game:

# %%
Grid()
# Out:
# Team #1: Philadelphia 76ers
# Team #2: Memphis Grizzlies
# Enter your player:  Danny Green
# Correct!
#
# Eligible players:
#  ['Anthony Tolliver', 'Jerryd Bayless', 'Danny Green', 'Elliot Williams', 'Darius Morris', 'Seth Curry', 'Tim Frazier', 'James Ennis III', 'Dakota Mathias', "De'Anthony Melton", 'Kenneth Lofton Jr.']
